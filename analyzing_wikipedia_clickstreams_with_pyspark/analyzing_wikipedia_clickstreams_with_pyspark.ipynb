# %% [markdown]
# # Analyzing Wikipedia Clickstream Data
# * [View Solution Notebook](./solution.html)
#
# * [Project Page Link](https://www.codecademy.com/courses/big-data-pyspark/projects/analyzing-wikipedia-pyspark)

# %% [markdown]
# ### Import Libraries

# %%
from pyspark.sql import SparkSession

# %% [markdown]
# ## Task Group 1 - Introduction to Clickstream Data

# %% [markdown]
# ### Task 1
# Create a new `SparkSession` and assign it to a variable named `spark`.

# %%
# Create a new SparkSession
spark = SparkSession.builder.getOrCreate()
# spark.stop()

# %% [markdown]
# ### Task 2
#
# Create an RDD from a list of sample clickstream counts and save it as `clickstream_counts_rdd`.

# %%
# Sample clickstream counts
sample_clickstream_counts = [
    ["other-search", "Hanging_Gardens_of_Babylon", "external", 47000],
    ["other-empty", "Hanging_Gardens_of_Babylon", "external", 34600],
    ["Wonders_of_the_World", "Hanging_Gardens_of_Babylon", "link", 14000],
    ["Babylon", "Hanging_Gardens_of_Babylon", "link", 2500]
]

# Create RDD from sample data
clickstream_counts_rdd = spark.sparkContext.parallelize(sample_clickstream_counts)
clickstream_counts_rdd.collect()
# Out:
# [['other-search', 'Hanging_Gardens_of_Babylon', 'external', 47000],
#  ['other-empty', 'Hanging_Gardens_of_Babylon', 'external', 34600],
#  ['Wonders_of_the_World', 'Hanging_Gardens_of_Babylon', 'link', 14000],
#  ['Babylon', 'Hanging_Gardens_of_Babylon', 'link', 2500]]

# %% [markdown]
# ### Task 3
#
# Using the RDD from the previous step, create a DataFrame named `clickstream_sample_df`

# %%
# Create a DataFrame from the RDD of sample clickstream counts
clickstream_sample_df = clickstream_counts_rdd.toDF(["source_page", "target_page", "link_category", "link_count"])

# Display the DataFrame to the notebook
clickstream_sample_df.printSchema()
clickstream_sample_df.show(truncate=False)
# Out:
# root
#  |-- source_page: string (nullable = true)
#  |-- target_page: string (nullable = true)
#  |-- link_category: string (nullable = true)
#  |-- link_count: long (nullable = true)
#
# +--------------------+--------------------------+-------------+----------+
# |source_page         |target_page               |link_category|link_count|
# +--------------------+--------------------------+-------------+----------+
# |other-search        |Hanging_Gardens_of_Babylon|external     |47000     |
# |other-empty         |Hanging_Gardens_of_Babylon|external     |34600     |
# |Wonders_of_the_World|Hanging_Gardens_of_Babylon|link         |14000     |
# |Babylon             |Hanging_Gardens_of_Babylon|link         |2500      |
# +--------------------+--------------------------+-------------+----------+

# %% [markdown]
# ## Task Group 2 - Inspecting Clickstream Data

# %% [markdown]
# ### Task 4
#
# Read the files in `./cleaned/clickstream/` into a new Spark DataFrame named `clickstream` and display the first few rows of the DataFrame in the notebook

# %%
# Read the target directory (`./cleaned/clickstream/`) into a DataFrame (`clickstream`)
clickstream_df = spark.read.\
option("header", True).\
option("delimiter", "\t").\
option("inferSchema", True).\
csv('./cleaned/clickstream/')

# Display the DataFrame to the notebook
clickstream_df.printSchema()
clickstream_df.show(10, truncate=False)
# Out:
# root
#  |-- referrer: string (nullable = true)
#  |-- resource: string (nullable = true)
#  |-- link_category: string (nullable = true)
#  |-- language_code: string (nullable = true)
#  |-- click_count: integer (nullable = true)
#
# +-------------------+--------------------------+-------------+-------------+-----------+
# |referrer           |resource                  |link_category|language_code|click_count|
# +-------------------+--------------------------+-------------+-------------+-----------+
# |Daniel_Day-Lewis   |Phantom_Thread            |link         |en           |43190      |
# |other-internal     |Phantom_Thread            |external     |en           |21683      |
# |other-empty        |Phantom_Thread            |external     |en           |169532     |
# |90th_Academy_Awards|Phantom_Thread            |link         |en           |40449      |
# |other-search       |Phantom_Thread            |external     |en           |536940     |
# |other-search       |Tara_Grinstead_murder_case|external     |en           |30041      |
# |other-search       |Yossi_Benayoun            |external     |en           |11045      |
# |other-empty        |Parthiv_Patel             |external     |en           |11481      |
# |other-search       |Parthiv_Patel             |external     |en           |34953      |
# |other-empty        |Cosimo_de'_Medici         |external     |en           |16418      |
# +-------------------+--------------------------+-------------+-------------+-----------+
# only showing top 10 rows

# %% [markdown]
# ### Task 5
#
# Print the schema of the DataFrame in the notebook.

# %%
# Display the schema of the `clickstream` DataFrame to the notebook
# clickstream.drop("language_code")
clickstream_df.printSchema()
# Out:
# root
#  |-- referrer: string (nullable = true)
#  |-- resource: string (nullable = true)
#  |-- link_category: string (nullable = true)
#  |-- language_code: string (nullable = true)
#  |-- click_count: integer (nullable = true)

# %% [markdown]
# ### Task 6
#
# Drop the `language_code` column from the DataFrame and display the new schema in the notebook.

# %%
# Drop target columns
clickstream_df = clickstream_df.drop("language_code")
# Display the first few rows of the DataFrame
clickstream_df.show(10, truncate=False)
# Display the new schema in the notebook
clickstream_df.printSchema()
# Out:
# +-------------------+--------------------------+-------------+-----------+
# |referrer           |resource                  |link_category|click_count|
# +-------------------+--------------------------+-------------+-----------+
# |Daniel_Day-Lewis   |Phantom_Thread            |link         |43190      |
# |other-internal     |Phantom_Thread            |external     |21683      |
# |other-empty        |Phantom_Thread            |external     |169532     |
# |90th_Academy_Awards|Phantom_Thread            |link         |40449      |
# |other-search       |Phantom_Thread            |external     |536940     |
# |other-search       |Tara_Grinstead_murder_case|external     |30041      |
# |other-search       |Yossi_Benayoun            |external     |11045      |
# |other-empty        |Parthiv_Patel             |external     |11481      |
# |other-search       |Parthiv_Patel             |external     |34953      |
# |other-empty        |Cosimo_de'_Medici         |external     |16418      |
# +-------------------+--------------------------+-------------+-----------+
# only showing top 10 rows
#
# root
#  |-- referrer: string (nullable = true)
#  |-- resource: string (nullable = true)
#  |-- link_category: string (nullable = true)
#  |-- click_count: integer (nullable = true)

# %% [markdown]
# ### Task 7
#
# Rename `referrer` and `resource` to `source_page` and `target_page`, respectively,

# %%
# Rename `referrer` and `resource` to `source_page` and `target_page`
clickstream_df = clickstream_df.withColumnRenamed("referrer", "source_page").withColumnRenamed("resource", "target_page")
  
# Display the first few rows of the DataFrame
clickstream_df.show(10, truncate=False)
# Display the new schema in the notebook
clickstream_df.printSchema()
# Out:
# +-------------------+--------------------------+-------------+-----------+
# |source_page        |target_page               |link_category|click_count|
# +-------------------+--------------------------+-------------+-----------+
# |Daniel_Day-Lewis   |Phantom_Thread            |link         |43190      |
# |other-internal     |Phantom_Thread            |external     |21683      |
# |other-empty        |Phantom_Thread            |external     |169532     |
# |90th_Academy_Awards|Phantom_Thread            |link         |40449      |
# |other-search       |Phantom_Thread            |external     |536940     |
# |other-search       |Tara_Grinstead_murder_case|external     |30041      |
# |other-search       |Yossi_Benayoun            |external     |11045      |
# |other-empty        |Parthiv_Patel             |external     |11481      |
# |other-search       |Parthiv_Patel             |external     |34953      |
# |other-empty        |Cosimo_de'_Medici         |external     |16418      |
# +-------------------+--------------------------+-------------+-----------+
# only showing top 10 rows
#
# root
#  |-- source_page: string (nullable = true)
#  |-- target_page: string (nullable = true)
#  |-- link_category: string (nullable = true)
#  |-- click_count: integer (nullable = true)

# %% [markdown]
# ## Task Group 3 - Querying Clickstream Data

# %% [markdown]
# ### Task 8
#
# Add the `clickstream` DataFrame as a temporary view named `clickstream` to make the data queryable with `sparkSession.sql()`

# %%
# Create a temporary view in the metadata for this `SparkSession` 
clickstream_df.createOrReplaceTempView("clickstream_view")

# %% [markdown]
# ### Task 9
#
# Filter the dataset to entries with `Hanging_Gardens_of_Babylon` as the `target_page` and order the result by `click_count` using PySpark DataFrame methods.

# %%
# Filter and sort the DataFrame using PySpark DataFrame methods
spark.catalog.listTables()
# Out:
# [Table(name='clickstream', catalog=None, namespace=[], description=None, tableType='TEMPORARY', isTemporary=True),
#  Table(name='clickstream_view', catalog=None, namespace=[], description=None, tableType='TEMPORARY', isTemporary=True)]

# %%
babylon_table = spark.read.table("clickstream_view")
babylon_table.count()
babylon_table.collect()
# Out:
# [Row(source_page='Daniel_Day-Lewis', target_page='Phantom_Thread', link_category='link', click_count=43190),
#  Row(source_page='other-internal', target_page='Phantom_Thread', link_category='external', click_count=21683),
#  Row(source_page='other-empty', target_page='Phantom_Thread', link_category='external', click_count=169532),
#  Row(source_page='90th_Academy_Awards', target_page='Phantom_Thread', link_category='link', click_count=40449),
#  Row(source_page='other-search', target_page='Phantom_Thread', link_category='external', click_count=536940),
#  Row(source_page='other-search', target_page='Tara_Grinstead_murder_case', link_category='external', click_count=30041),
#  Row(source_page='other-search', target_page='Yossi_Benayoun', link_category='external', click_count=11045),
#  Row(source_page='other-empty', target_page='Parthiv_Patel', link_category='external', click_count=11481),
#  Row(source_page='other-search', target_page='Parthiv_Patel', link_category='external', click_count=34953),
#  Row(source_page='other-empty', target_page="Cosimo_de'_Medici", link_category='external', click_count=16418),
#  Row(source_page='other-search', target_page="Cosimo_de'_Medici", link_category='external', click_count=22190),
#  Row(source_page='other-search', target_page='University_of_Georgia', link_category='external', click_count=29963),
#  Row(source_page='other-empty', target_page='University_of_Georgia', link_category='external', click_count=17325),
#  Row(source_page='other-search', target_page='Carbon_monoxide_detector', link_category='external', click_count=13617),
#  Row(source_page='other-empty', target_page='Marissa_Ribisi', link_category='external', click_count=18979),
#  Row(source_page='Shinee', target_page='Kim_Jong-hyun_(singer)', link_category='link', click_count=24433),
#  Row(source_page='other-search', target_page='Kim_Jong-hyun_(singer)', link_category='external', click_count=162466),
#  Row(source_page='other-empty', target_page='Kim_Jong-hyun_(singer)', link_category='external', click_count=60193),
#  Row(source_page='other-empty', target_page='Hello_Kitty', link_category='external', click_count=10674),
#  Row(source_page='other-search', target_page='Hello_Kitty', link_category='external', click_count=23726),
#  Row(source_page='other-search', target_page='SEAT_Ibiza', link_category='external', click_count=13450),
#  Row(source_page='other-search', target_page='Orgy', link_category='external', click_count=15355),
#  Row(source_page='other-search', target_page='Idiopathic_intracranial_hypertension', link_category='external', click_count=15571),
#  Row(source_page='other-empty', target_page='Yeovil_Town_F.C.', link_category='external', click_count=22249),
#  Row(source_page='other-search', target_page='Yeovil_Town_F.C.', link_category='external', click_count=69574),
#  Row(source_page='other-empty', target_page='Ariane_Labed', link_category='external', click_count=10252),
#  Row(source_page='other-search', target_page='Electric_eel', link_category='external', click_count=21413),
#  Row(source_page='other-search', target_page='List_of_Will_&_Grace_episodes', link_category='external', click_count=12296),
#  Row(source_page='other-empty', target_page='List_of_Will_&_Grace_episodes', link_category='external', click_count=37258),
#  Row(source_page='other-search', target_page='Jonah_Lomu', link_category='external', click_count=11962),
#  Row(source_page='other-empty', target_page='Pradhan_Mantri_Gramin_Awaas_Yojana', link_category='external', click_count=13989),
#  Row(source_page='other-search', target_page='Pradhan_Mantri_Gramin_Awaas_Yojana', link_category='external', click_count=26581),
#  Row(source_page='other-empty', target_page='Sauron', link_category='external', click_count=28601),
#  Row(source_page='other-search', target_page='Alyssa_Sutherland', link_category='external', click_count=20523),
#  Row(source_page='other-empty', target_page='Alyssa_Sutherland', link_category='external', click_count=17559),
#  Row(source_page='other-search', target_page='Sauron', link_category='external', click_count=32604),
#  Row(source_page='other-search', target_page='EEPROM', link_category='external', click_count=11182),
#  Row(source_page='other-search', target_page='Yootha_Joyce', link_category='external', click_count=13377),
#  Row(source_page='other-empty', target_page='Tracy_Reiner', link_category='external', click_count=13018),
#  Row(source_page='other-search', target_page='Procedural_programming', link_category='external', click_count=10325),
#  Row(source_page='other-search', target_page='Sciatic_nerve', link_category='external', click_count=15868),
#  Row(source_page='other-empty', target_page='Sciatic_nerve', link_category='external', click_count=14073),
#  Row(source_page='other-empty', target_page='Rhythm_and_blues', link_category='external', click_count=16757),
#  Row(source_page='other-search', target_page='Rhythm_and_blues', link_category='external', click_count=22137),
#  Row(source_page='other-search', target_page='Alexandra_Palace', link_category='external', click_count=12228),
#  Row(source_page='other-empty', target_page='Citric_acid_cycle', link_category='external', click_count=18900),
#  Row(source_page='other-search', target_page='Citric_acid_cycle', link_category='external', click_count=48888),
#  Row(source_page='other-search', target_page='Victoria_(Australia)', link_category='external', click_count=12180),
#  Row(source_page='other-empty', target_page='Victoria_(Australia)', link_category='external', click_count=16968),
#  Row(source_page='other-search', target_page='India–Pakistan_border', link_category='external', click_count=16588),
#  Row(source_page='other-empty', target_page='Dungeons_&_Dragons', link_category='external', click_count=23970),
#  Row(source_page='other-search', target_page='Dungeons_&_Dragons', link_category='external', click_count=56399),
#  Row(source_page='other-search', target_page='Dinah_Manoff', link_category='external', click_count=14573),
#  Row(source_page='other-empty', target_page='Dinah_Manoff', link_category='external', click_count=11313),
#  Row(source_page='other-search', target_page='Sha_Na_Na', link_category='external', click_count=11339),
#  Row(source_page='other-search', target_page='Skandar_Keynes', link_category='external', click_count=11958),
#  Row(source_page='other-empty', target_page='Skandar_Keynes', link_category='external', click_count=10565),
#  Row(source_page='Agnyaathavaasi', target_page='Anu_Emmanuel', link_category='link', click_count=15020),
#  Row(source_page='Naa_Peru_Surya', target_page='Anu_Emmanuel', link_category='link', click_count=12361),
#  Row(source_page='other-empty', target_page='Anu_Emmanuel', link_category='external', click_count=24024),
#  Row(source_page='other-search', target_page='Anu_Emmanuel', link_category='external', click_count=58999),
#  Row(source_page='other-search', target_page='Hyundai_Genesis_Coupe', link_category='external', click_count=17484),
#  Row(source_page='other-search', target_page='Justice_League_(TV_series)', link_category='external', click_count=13967),
#  Row(source_page='other-empty', target_page='Utahraptor', link_category='external', click_count=11019),
#  Row(source_page='other-search', target_page='42nd_Street_(musical)', link_category='external', click_count=17506),
#  Row(source_page='other-empty', target_page='Alkaloid', link_category='external', click_count=11218),
#  Row(source_page='other-search', target_page='Alkaloid', link_category='external', click_count=16274),
#  Row(source_page='other-search', target_page='Forest', link_category='external', click_count=35132),
#  Row(source_page='other-empty', target_page='Forest', link_category='external', click_count=20839),
#  Row(source_page='other-empty', target_page='Ann_Widdecombe', link_category='external', click_count=70466),
#  Row(source_page='other-search', target_page='Ann_Widdecombe', link_category='external', click_count=161298),
#  Row(source_page='other-search', target_page='Rod_Laver_Arena', link_category='external', click_count=14215),
#  Row(source_page='other-search', target_page='The_Lego_Movie_(franchise)', link_category='external', click_count=11240),
#  Row(source_page='other-empty', target_page='The_Lego_Movie_(franchise)', link_category='external', click_count=22103),
#  Row(source_page='other-search', target_page='Eve_Online', link_category='external', click_count=20394),
#  Row(source_page='Mariah_Carey', target_page='Nick_Cannon', link_category='link', click_count=16214),
#  Row(source_page='other-search', target_page='Selah', link_category='external', click_count=16516),
#  Row(source_page='other-empty', target_page='Nick_Cannon', link_category='external', click_count=48598),
#  Row(source_page='other-search', target_page='Nick_Cannon', link_category='external', click_count=70070),
#  Row(source_page='other-search', target_page='Topaz', link_category='external', click_count=17199),
#  Row(source_page='other-search', target_page='M1_Abrams', link_category='external', click_count=49500),
#  Row(source_page='other-empty', target_page='M1_Abrams', link_category='external', click_count=26404),
#  Row(source_page='other-empty', target_page='PartyNextDoor', link_category='external', click_count=11033),
#  Row(source_page='other-search', target_page='PartyNextDoor', link_category='external', click_count=12660),
#  Row(source_page='other-empty', target_page='Maz_Kanata', link_category='external', click_count=15157),
#  Row(source_page='other-empty', target_page='The_Lonely_Island', link_category='external', click_count=14602),
#  Row(source_page='other-search', target_page='The_Lonely_Island', link_category='external', click_count=24548),
#  Row(source_page='other-empty', target_page='Fear_and_Loathing_in_Las_Vegas', link_category='external', click_count=10493),
#  Row(source_page='other-search', target_page='Fear_and_Loathing_in_Las_Vegas', link_category='external', click_count=11255),
#  Row(source_page='other-search', target_page='Bonnie_Rotten', link_category='external', click_count=20914),
#  Row(source_page='other-empty', target_page='Pathological_lying', link_category='external', click_count=10520),
#  Row(source_page='other-search', target_page='Pathological_lying', link_category='external', click_count=40726),
#  Row(source_page='other-search', target_page='Boeing_EA-18G_Growler', link_category='external', click_count=15490),
#  Row(source_page='other-empty', target_page='Boeing_EA-18G_Growler', link_category='external', click_count=10381),
#  Row(source_page='other-search', target_page='Lee_Norris', link_category='external', click_count=16362),
#  Row(source_page='other-search', target_page='Stalking', link_category='external', click_count=17664),
#  Row(source_page='other-empty', target_page='Stalking', link_category='external', click_count=10566),
#  Row(source_page='other-search', target_page='Pride_(2014_film)', link_category='external', click_count=15512),
#  Row(source_page='other-search', target_page='List_of_countries_by_foreign-exchange_reserves', link_category='external', click_count=19063),
#  Row(source_page='other-search', target_page='Defamation', link_category='external', click_count=23792),
#  Row(source_page='other-empty', target_page='Defamation', link_category='external', click_count=23297),
#  Row(source_page='other-search', target_page='Boundaries_between_the_continents_of_Earth', link_category='external', click_count=13335),
#  Row(source_page='other-search', target_page='Time_series', link_category='external', click_count=25174),
#  Row(source_page='other-search', target_page='Nacre', link_category='external', click_count=10722),
#  Row(source_page='other-empty', target_page='List_of_Made_in_Chelsea_cast_members', link_category='external', click_count=12676),
#  Row(source_page='other-empty', target_page='NCAA_Division_I', link_category='external', click_count=41519),
#  Row(source_page='other-search', target_page='NCAA_Division_I', link_category='external', click_count=16012),
#  Row(source_page='other-search', target_page='Deadmau5', link_category='external', click_count=46509),
#  Row(source_page='other-empty', target_page='Deadmau5', link_category='external', click_count=17998),
#  Row(source_page='other-search', target_page='Tournament_of_Champions_(golf)', link_category='external', click_count=10645),
#  Row(source_page='other-search', target_page='White_privilege', link_category='external', click_count=26995),
#  Row(source_page='other-empty', target_page='Nikki_Amuka-Bird', link_category='external', click_count=12772),
#  Row(source_page='other-search', target_page='Nikki_Amuka-Bird', link_category='external', click_count=11324),
#  Row(source_page='Kesha', target_page='Rainbow_(Kesha_album)', link_category='link', click_count=11448),
#  Row(source_page='other-search', target_page='Rainbow_(Kesha_album)', link_category='external', click_count=14484),
#  Row(source_page='other-empty', target_page='Rainbow_(Kesha_album)', link_category='external', click_count=18154),
#  Row(source_page='other-search', target_page='1_Night_in_Paris', link_category='external', click_count=13576),
#  Row(source_page='other-empty', target_page='1_Night_in_Paris', link_category='external', click_count=13059),
#  Row(source_page='other-empty', target_page='Patroclus', link_category='external', click_count=10175),
#  Row(source_page='other-search', target_page='Configuration_management', link_category='external', click_count=12398),
#  Row(source_page='other-search', target_page='Anarkali', link_category='external', click_count=17740),
#  Row(source_page='other-search', target_page='Irish_language', link_category='external', click_count=24064),
#  Row(source_page='other-empty', target_page='Irish_language', link_category='external', click_count=20453),
#  Row(source_page='other-search', target_page='Rook_(chess)', link_category='external', click_count=12706),
#  Row(source_page='other-empty', target_page='Alexander_Fleming', link_category='external', click_count=14053),
#  Row(source_page='other-search', target_page='Alexander_Fleming', link_category='external', click_count=35403),
#  Row(source_page='other-search', target_page='Jodha_Akbar_(TV_series)', link_category='external', click_count=14861),
#  Row(source_page='other-search', target_page='Fourth_Reich', link_category='external', click_count=13374),
#  Row(source_page='other-search', target_page='History_of_Microsoft', link_category='external', click_count=12749),
#  Row(source_page='other-search', target_page='Organizational_behavior', link_category='external', click_count=18235),
#  Row(source_page='other-empty', target_page='PlayStation_2', link_category='external', click_count=24394),
#  Row(source_page='other-search', target_page='PlayStation_2', link_category='external', click_count=31917),
#  Row(source_page='other-search', target_page='Shipping_(fandom)', link_category='external', click_count=11725),
#  Row(source_page='other-search', target_page='Madeira', link_category='external', click_count=32403),
#  Row(source_page='other-empty', target_page='Madeira', link_category='external', click_count=24280),
#  Row(source_page='other-search', target_page='Iron-deficiency_anemia', link_category='external', click_count=15654),
#  Row(source_page='other-search', target_page='Continental_Army', link_category='external', click_count=10231),
#  Row(source_page='other-search', target_page='Salt', link_category='external', click_count=37868),
#  Row(source_page='other-empty', target_page='Salt', link_category='external', click_count=15940),
#  Row(source_page='other-search', target_page='Max_Planck', link_category='external', click_count=16198),
#  Row(source_page='other-search', target_page='Simplex_algorithm', link_category='external', click_count=10581),
#  Row(source_page='other-empty', target_page='Simplex_algorithm', link_category='external', click_count=12388),
#  Row(source_page='other-search', target_page='Cooking', link_category='external', click_count=11762),
#  Row(source_page='other-search', target_page='Cruella_de_Vil', link_category='external', click_count=13364),
#  Row(source_page='other-search', target_page='Korean_Air_Flight_858', link_category='external', click_count=19759),
#  Row(source_page='other-search', target_page='Robin_Meade', link_category='external', click_count=22568),
#  Row(source_page='other-empty', target_page='Robin_Meade', link_category='external', click_count=10805),
#  Row(source_page='other-search', target_page='Small_intestine', link_category='external', click_count=32023),
#  Row(source_page='other-empty', target_page='Small_intestine', link_category='external', click_count=15832),
#  Row(source_page='other-search', target_page='2018_G20_Buenos_Aires_summit', link_category='external', click_count=14987),
#  Row(source_page='other-empty', target_page='John_Attenborough', link_category='external', click_count=20884),
#  Row(source_page='David_Attenborough', target_page='John_Attenborough', link_category='link', click_count=11252),
#  Row(source_page='other-empty', target_page='Lex_Luger', link_category='external', click_count=17008),
#  Row(source_page='other-search', target_page='Lex_Luger', link_category='external', click_count=24487),
#  Row(source_page='other-search', target_page='List_of_mobile_phone_makers_by_country', link_category='external', click_count=109147),
#  Row(source_page='other-empty', target_page='List_of_mobile_phone_makers_by_country', link_category='external', click_count=36626),
#  Row(source_page='other-empty', target_page='Joe_Armstrong_(actor)', link_category='external', click_count=12924),
#  Row(source_page='other-search', target_page='Hollywood_blacklist', link_category='external', click_count=25273),
#  Row(source_page='other-empty', target_page='Hollywood_blacklist', link_category='external', click_count=19909),
#  Row(source_page='other-search', target_page='John_Lee_Hooker', link_category='external', click_count=10017),
#  Row(source_page='other-search', target_page='Saracen', link_category='external', click_count=26230),
#  Row(source_page='other-empty', target_page='Saracen', link_category='external', click_count=10023),
#  Row(source_page='other-search', target_page='Collective_Soul', link_category='external', click_count=14422),
#  Row(source_page='other-empty', target_page='Meredith_Vieira', link_category='external', click_count=11927),
#  Row(source_page='other-search', target_page='Jennifer_Lawrence', link_category='external', click_count=269752),
#  Row(source_page='other-empty', target_page='Jennifer_Lawrence', link_category='external', click_count=125378),
#  Row(source_page='other-search', target_page='Thirty_Seconds_to_Mars', link_category='external', click_count=51265),
#  Row(source_page='other-empty', target_page='Thirty_Seconds_to_Mars', link_category='external', click_count=19800),
#  Row(source_page='other-empty', target_page='Spectre_(2015_film)', link_category='external', click_count=74731),
#  Row(source_page='other-search', target_page='Spectre_(2015_film)', link_category='external', click_count=134781),
#  Row(source_page='other-search', target_page='Boaz', link_category='external', click_count=13429),
#  Row(source_page='other-search', target_page='2017_PDC_World_Darts_Championship', link_category='external', click_count=16124),
#  Row(source_page='other-search', target_page='Brian_Orakpo', link_category='external', click_count=10944),
#  Row(source_page='Boney_M.', target_page='Bobby_Farrell', link_category='link', click_count=14095),
#  Row(source_page='other-search', target_page='List_of_Nintendo_Direct_presentations', link_category='external', click_count=33072),
#  Row(source_page='other-search', target_page='GMC_(automobile)', link_category='external', click_count=18596),
#  Row(source_page='The_End_of_the_F***ing_World', target_page='Jessica_Barden', link_category='link', click_count=237279),
#  Row(source_page='other-empty', target_page='Jessica_Barden', link_category='external', click_count=273132),
#  Row(source_page='other-search', target_page='Jessica_Barden', link_category='external', click_count=218431),
#  Row(source_page='other-search', target_page='List_of_nature_deities', link_category='external', click_count=26557),
#  Row(source_page='other-search', target_page='Ollolai', link_category='external', click_count=22107),
#  Row(source_page='Quentin_Tarantino', target_page='The_Hateful_Eight', link_category='link', click_count=12018),
#  Row(source_page='other-search', target_page='The_Hateful_Eight', link_category='external', click_count=85280),
#  Row(source_page='other-empty', target_page='The_Hateful_Eight', link_category='external', click_count=43961),
#  Row(source_page='other-empty', target_page='The_League_of_Gentlemen', link_category='external', click_count=15402),
#  Row(source_page='other-search', target_page='The_League_of_Gentlemen', link_category='external', click_count=31951),
#  Row(source_page='other-search', target_page='Eid_al-Fitr', link_category='external', click_count=22642),
#  Row(source_page='other-empty', target_page='Eid_al-Fitr', link_category='external', click_count=14933),
#  Row(source_page='other-search', target_page='Olivia_Cooke', link_category='external', click_count=13515),
#  Row(source_page='other-empty', target_page='Olivia_Cooke', link_category='external', click_count=33399),
#  Row(source_page='Ready_Player_One_(film)', target_page='Olivia_Cooke', link_category='link', click_count=17468),
#  Row(source_page='other-search', target_page='Derek_Fisher', link_category='external', click_count=15174),
#  Row(source_page='other-empty', target_page="Skene's_gland", link_category='external', click_count=10176),
#  Row(source_page='other-search', target_page="Skene's_gland", link_category='external', click_count=12020),
#  Row(source_page='other-empty', target_page='Davy_Jones_(musician)', link_category='external', click_count=13781),
#  Row(source_page='other-search', target_page='Iodine', link_category='external', click_count=35321),
#  Row(source_page='other-empty', target_page='Iodine', link_category='external', click_count=16966),
#  Row(source_page='other-search', target_page='Davy_Jones_(musician)', link_category='external', click_count=20087),
#  Row(source_page='other-search', target_page='Pablo_Carreño_Busta', link_category='external', click_count=10119),
#  Row(source_page='other-search', target_page='List_of_environmental_organizations', link_category='external', click_count=13435),
#  Row(source_page='other-empty', target_page='Blac_Chyna', link_category='external', click_count=28248),
#  Row(source_page='other-search', target_page='Blac_Chyna', link_category='external', click_count=46083),
#  Row(source_page='other-search', target_page='Wilhelm_II,_German_Emperor', link_category='external', click_count=74872),
#  Row(source_page='other-empty', target_page='Wilhelm_II,_German_Emperor', link_category='external', click_count=70866),
#  Row(source_page='other-search', target_page='School_holidays_in_the_United_States', link_category='external', click_count=30987),
#  Row(source_page='other-search', target_page='Marrakesh', link_category='external', click_count=26033),
#  Row(source_page='other-empty', target_page='Marrakesh', link_category='external', click_count=26402),
#  Row(source_page='Royal_Rumble_(2018)', target_page='Kevin_Owens_and_Sami_Zayn', link_category='link', click_count=11503),
#  Row(source_page='other-search', target_page='Forrest_Griffin', link_category='external', click_count=10674),
#  Row(source_page='other-search', target_page='Middlesbrough_F.C.', link_category='external', click_count=15880),
#  Row(source_page='other-empty', target_page='Middlesbrough_F.C.', link_category='external', click_count=18090),
#  Row(source_page='other-search', target_page='Public_Enemy_(band)', link_category='external', click_count=18018),
#  Row(source_page='other-empty', target_page='Public_Enemy_(band)', link_category='external', click_count=12993),
#  Row(source_page='other-search', target_page='Polydimethylsiloxane', link_category='external', click_count=18838),
#  Row(source_page='other-search', target_page='Free_Willy', link_category='external', click_count=13197),
#  Row(source_page='other-search', target_page='Union_(American_Civil_War)', link_category='external', click_count=14223),
#  Row(source_page='other-search', target_page='Marvel_vs._Capcom:_Infinite', link_category='external', click_count=30947),
#  Row(source_page='other-empty', target_page='Marvel_vs._Capcom:_Infinite', link_category='external', click_count=10417),
#  Row(source_page='other-empty', target_page='Victory_in_Europe_Day', link_category='external', click_count=10191),
#  Row(source_page='other-search', target_page='Victory_in_Europe_Day', link_category='external', click_count=10438),
#  Row(source_page='other-empty', target_page='Linda_Thompson_(actress)', link_category='external', click_count=27055),
#  Row(source_page='other-search', target_page='Linda_Thompson_(actress)', link_category='external', click_count=19685),
#  Row(source_page='other-empty', target_page='Plantar_fasciitis', link_category='external', click_count=74231),
#  Row(source_page='other-search', target_page='Plantar_fasciitis', link_category='external', click_count=28136),
#  Row(source_page='other-search', target_page='Sodium_chloride', link_category='external', click_count=48409),
#  Row(source_page='other-empty', target_page='Sodium_chloride', link_category='external', click_count=18247),
#  Row(source_page='other-empty', target_page='Dimension', link_category='external', click_count=11693),
#  Row(source_page='other-search', target_page='Dimension', link_category='external', click_count=23033),
#  Row(source_page='other-search', target_page='British_Hong_Kong', link_category='external', click_count=10218),
#  Row(source_page='other-search', target_page='Gerry_Rafferty', link_category='external', click_count=19121),
#  Row(source_page='other-search', target_page='Yi_Sun-sin', link_category='external', click_count=12190),
#  Row(source_page='other-search', target_page='Acetic_anhydride', link_category='external', click_count=10018),
#  Row(source_page='other-search', target_page='Marcus_Aurelius', link_category='external', click_count=71048),
#  Row(source_page='other-empty', target_page='Marcus_Aurelius', link_category='external', click_count=36664),
#  Row(source_page='other-empty', target_page='Almost_Famous', link_category='external', click_count=24981),
#  Row(source_page='other-search', target_page='Almost_Famous', link_category='external', click_count=38536),
#  Row(source_page='other-search', target_page='Dede_Westbrook', link_category='external', click_count=16998),
#  Row(source_page='other-search', target_page='Respiratory_sounds', link_category='external', click_count=17022),
#  Row(source_page='other-empty', target_page='Chris_Noth', link_category='external', click_count=20109),
#  Row(source_page='other-search', target_page='Chris_Noth', link_category='external', click_count=24819),
#  Row(source_page='other-search', target_page='Brenda_Song', link_category='external', click_count=45435),
#  Row(source_page='other-empty', target_page='Brenda_Song', link_category='external', click_count=38725),
#  Row(source_page='Macaulay_Culkin', target_page='Brenda_Song', link_category='link', click_count=20477),
#  Row(source_page='other-search', target_page='DayZ_(video_game)', link_category='external', click_count=16731),
#  Row(source_page='other-search', target_page='Toyota_Previa', link_category='external', click_count=13311),
#  Row(source_page='other-search', target_page='Rizzle_Kicks', link_category='external', click_count=14489),
#  Row(source_page='other-search', target_page='Visa_requirements_for_Turkish_citizens', link_category='external', click_count=13327),
#  Row(source_page='other-search', target_page='Beta_distribution', link_category='external', click_count=31645),
#  Row(source_page='other-search', target_page='List_of_United_States_Army_careers', link_category='external', click_count=10657),
#  Row(source_page='other-search', target_page='Thinking_Out_Loud', link_category='external', click_count=12414),
#  Row(source_page='other-search', target_page='Private_Practice_(TV_series)', link_category='external', click_count=20392),
#  Row(source_page='other-empty', target_page='Private_Practice_(TV_series)', link_category='external', click_count=19347),
#  Row(source_page='other-empty', target_page='Vivo_(smartphone)', link_category='external', click_count=10684),
#  Row(source_page='other-search', target_page='Vivo_(smartphone)', link_category='external', click_count=40645),
#  Row(source_page='other-search', target_page='Sanath_Jayasuriya', link_category='external', click_count=19355),
#  Row(source_page='other-internal', target_page='RMS_Titanic', link_category='external', click_count=11232),
#  Row(source_page='other-empty', target_page='RMS_Titanic', link_category='external', click_count=103217),
#  Row(source_page='other-search', target_page='Michael_Madsen', link_category='external', click_count=20286),
#  Row(source_page='other-empty', target_page='Michael_Madsen', link_category='external', click_count=25204),
#  Row(source_page='Altered_Carbon', target_page='Altered_Carbon_(TV_series)', link_category='link', click_count=23962),
#  Row(source_page='other-search', target_page='RMS_Titanic', link_category='external', click_count=297538),
#  Row(source_page='other-search', target_page='Altered_Carbon_(TV_series)', link_category='external', click_count=124757),
#  Row(source_page='other-empty', target_page='Altered_Carbon_(TV_series)', link_category='external', click_count=40074),
#  Row(source_page='Lil_Pump', target_page='Smokepurpp', link_category='link', click_count=36736),
#  Row(source_page='other-empty', target_page='Smokepurpp', link_category='external', click_count=42953),
#  Row(source_page='other-search', target_page='Smokepurpp', link_category='external', click_count=19891),
#  Row(source_page='other-search', target_page='Guess_(clothing)', link_category='external', click_count=10866),
#  Row(source_page='other-search', target_page='Ethylene_glycol', link_category='external', click_count=32553),
#  Row(source_page='other-empty', target_page='List_of_television_series_based_on_DC_Comics', link_category='external', click_count=12009),
#  Row(source_page='other-search', target_page='List_of_television_series_based_on_DC_Comics', link_category='external', click_count=36163),
#  Row(source_page='other-search', target_page='Mahayana', link_category='external', click_count=11773),
#  Row(source_page='other-empty', target_page='Mahayana', link_category='external', click_count=10299),
#  Row(source_page='other-empty', target_page='Happy_Death_Day', link_category='external', click_count=50978),
#  Row(source_page='other-search', target_page='Happy_Death_Day', link_category='external', click_count=197418),
#  Row(source_page='Fifth_Harmony', target_page='Camila_Cabello', link_category='link', click_count=30959),
#  Row(source_page='other-internal', target_page='Camila_Cabello', link_category='external', click_count=20484),
#  Row(source_page='Havana_(Camila_Cabello_song)', target_page='Camila_Cabello', link_category='link', click_count=12803),
#  Row(source_page='other-empty', target_page='Camila_Cabello', link_category='external', click_count=231179),
#  Row(source_page='other-search', target_page='Camila_Cabello', link_category='external', click_count=894281),
#  Row(source_page='other-search', target_page='Single_malt_whisky', link_category='external', click_count=14365),
#  Row(source_page='other-search', target_page='Vic_Morrow', link_category='external', click_count=19278),
#  Row(source_page='other-empty', target_page='Vic_Morrow', link_category='external', click_count=16235),
#  Row(source_page='other-search', target_page='Titus', link_category='external', click_count=10604),
#  Row(source_page='other-empty', target_page='Titus', link_category='external', click_count=11094),
#  Row(source_page='other-search', target_page='The_Morrígan', link_category='external', click_count=16735),
#  Row(source_page='other-search', target_page='Reaction_rate_constant', link_category='external', click_count=10681),
#  Row(source_page='other-search', target_page='Battle_of_Midway', link_category='external', click_count=40740),
#  Row(source_page='other-empty', target_page='Battle_of_Midway', link_category='external', click_count=20757),
#  Row(source_page='other-search', target_page='Matthew_Hayden', link_category='external', click_count=10089),
#  Row(source_page='other-search', target_page='Depleted_uranium', link_category='external', click_count=10316),
#  Row(source_page='other-search', target_page='Bet365', link_category='external', click_count=20467),
#  Row(source_page='other-search', target_page='Michelle_Trachtenberg', link_category='external', click_count=44192),
#  Row(source_page='other-empty', target_page='Michelle_Trachtenberg', link_category='external', click_count=21485),
#  Row(source_page='other-search', target_page='Haikyu!!', link_category='external', click_count=23739),
#  Row(source_page='other-search', target_page='Guardians_of_the_Galaxy_(film)', link_category='external', click_count=104939),
#  Row(source_page='other-empty', target_page='Guardians_of_the_Galaxy_(film)', link_category='external', click_count=54301),
#  Row(source_page='other-search', target_page='Maci_Bookout', link_category='external', click_count=20858),
#  Row(source_page='other-empty', target_page='Tituss_Burgess', link_category='external', click_count=12033),
#  Row(source_page='other-search', target_page='Tituss_Burgess', link_category='external', click_count=21242),
#  Row(source_page='other-search', target_page='Seppuku', link_category='external', click_count=58518),
#  Row(source_page='other-empty', target_page='Seppuku', link_category='external', click_count=45395),
#  Row(source_page='other-search', target_page='Epithelium', link_category='external', click_count=35901),
#  Row(source_page='other-empty', target_page='Epithelium', link_category='external', click_count=22148),
#  Row(source_page='other-empty', target_page='Denmark', link_category='external', click_count=82196),
#  Row(source_page='other-search', target_page='Denmark', link_category='external', click_count=103893),
#  Row(source_page='other-search', target_page='Pointless', link_category='external', click_count=12066),
#  Row(source_page='other-search', target_page="2019_World_Men's_Handball_Championship", link_category='external', click_count=17008),
#  Row(source_page='other-empty', target_page='Q-Tip_(musician)', link_category='external', click_count=12710),
#  Row(source_page='other-search', target_page='Boston_Celtics', link_category='external', click_count=48235),
#  Row(source_page='other-empty', target_page='Boston_Celtics', link_category='external', click_count=33008),
#  Row(source_page='other-search', target_page='Q-Tip_(musician)', link_category='external', click_count=12993),
#  Row(source_page='other-search', target_page='Michael_Alig', link_category='external', click_count=11046),
#  Row(source_page='other-empty', target_page='Dumbo_(2019_film)', link_category='external', click_count=19712),
#  Row(source_page='other-search', target_page='John_Aniston', link_category='external', click_count=12935),
#  Row(source_page='other-empty', target_page='John_Aniston', link_category='external', click_count=47126),
#  Row(source_page='Jennifer_Aniston', target_page='John_Aniston', link_category='link', click_count=26498),
#  Row(source_page='other-search', target_page='Bhutu', link_category='external', click_count=12123),
#  Row(source_page='other-search', target_page='Triangle_inequality', link_category='external', click_count=14221),
#  Row(source_page='Kingsman:_The_Golden_Circle', target_page='Kingsman:_The_Secret_Service', link_category='link', click_count=11969),
#  Row(source_page='other-empty', target_page='Kingsman:_The_Secret_Service', link_category='external', click_count=47702),
#  Row(source_page='other-search', target_page='Kingsman:_The_Secret_Service', link_category='external', click_count=139427),
#  Row(source_page='other-search', target_page='Kansai_International_Airport', link_category='external', click_count=10579),
#  Row(source_page='other-search', target_page='Meri_Durga', link_category='external', click_count=30169),
#  Row(source_page='other-empty', target_page='Meri_Durga', link_category='external', click_count=14874),
#  Row(source_page='other-search', target_page='Application_for_employment', link_category='external', click_count=10350),
#  Row(source_page='other-search', target_page='Slobodan_Praljak', link_category='external', click_count=23608),
#  Row(source_page='other-empty', target_page='Online_dating_service', link_category='external', click_count=21815),
#  Row(source_page='other-search', target_page='Catalan_language', link_category='external', click_count=11899),
#  Row(source_page='other-empty', target_page='Catalan_language', link_category='external', click_count=13398),
#  Row(source_page='other-search', target_page='Homosexuality_in_India', link_category='external', click_count=16351),
#  Row(source_page='other-search', target_page='Balthus', link_category='external', click_count=10137),
#  Row(source_page='other-search', target_page='Hạ_Long_Bay', link_category='external', click_count=14834),
#  Row(source_page='other-search', target_page='Luke_Perry', link_category='external', click_count=39790),
#  Row(source_page='other-empty', target_page='Luke_Perry', link_category='external', click_count=26816),
#  Row(source_page='other-search', target_page='Chamillionaire', link_category='external', click_count=20774),
#  Row(source_page='other-search', target_page='Oakland_Raiders', link_category='external', click_count=81804),
#  Row(source_page='other-empty', target_page='Oakland_Raiders', link_category='external', click_count=57910),
#  Row(source_page='other-empty', target_page='List_of_Neighbours_characters', link_category='external', click_count=16989),
#  Row(source_page='other-search', target_page='List_of_Neighbours_characters', link_category='external', click_count=21492),
#  Row(source_page='other-empty', target_page='Maud_of_Wales', link_category='external', click_count=17309),
#  Row(source_page='other-search', target_page='Road_House_(1989_film)', link_category='external', click_count=21588),
#  Row(source_page='other-empty', target_page='Road_House_(1989_film)', link_category='external', click_count=12634),
#  Row(source_page='other-search', target_page="RuPaul's_Drag_Race_(season_7)", link_category='external', click_count=28739),
#  Row(source_page='other-empty', target_page="RuPaul's_Drag_Race_(season_7)", link_category='external', click_count=18853),
#  Row(source_page='other-search', target_page='Autofellatio', link_category='external', click_count=13597),
#  Row(source_page='other-empty', target_page='Autofellatio', link_category='external', click_count=13541),
#  Row(source_page='Ana_de_Armas', target_page='Marc_Clotet', link_category='link', click_count=23739),
#  Row(source_page='other-empty', target_page='Marc_Clotet', link_category='external', click_count=20921),
#  Row(source_page='other-search', target_page='Dichloromethane', link_category='external', click_count=22237),
#  Row(source_page='other-empty', target_page='Pernell_Roberts', link_category='external', click_count=12911),
#  Row(source_page='other-search', target_page='Pernell_Roberts', link_category='external', click_count=30507),
#  Row(source_page='Dan_Levy_(TV_personality)', target_page='Sarah_Levy', link_category='link', click_count=10945),
#  Row(source_page='other-empty', target_page='Sarah_Levy', link_category='external', click_count=31813),
#  Row(source_page='other-search', target_page='Sarah_Levy', link_category='external', click_count=12033),
#  Row(source_page='other-search', target_page='Futurama', link_category='external', click_count=46944),
#  Row(source_page='other-empty', target_page='Futurama', link_category='external', click_count=24064),
#  Row(source_page='other-empty', target_page='Bechdel_test', link_category='external', click_count=22461),
#  Row(source_page='other-search', target_page='Bechdel_test', link_category='external', click_count=74953),
#  Row(source_page='other-search', target_page='Mason_Rudolph_(American_football)', link_category='external', click_count=14913),
#  Row(source_page='other-empty', target_page='Tadalafil', link_category='external', click_count=14118),
#  Row(source_page='other-search', target_page='Tadalafil', link_category='external', click_count=22383),
#  Row(source_page='other-search', target_page='Boer', link_category='external', click_count=11039),
#  Row(source_page='other-search', target_page='Powder_(film)', link_category='external', click_count=10795),
#  Row(source_page='other-search', target_page='Sigrid_Valdis', link_category='external', click_count=14145),
#  Row(source_page='other-search', target_page='Elf_(film)', link_category='external', click_count=15115),
#  Row(source_page='other-search', target_page='Scotch_bonnet', link_category='external', click_count=13574),
#  Row(source_page='other-search', target_page='Cascada', link_category='external', click_count=11682),
#  Row(source_page='other-empty', target_page='Rothschild_family', link_category='external', click_count=68144),
#  Row(source_page='other-search', target_page='Rothschild_family', link_category='external', click_count=153773),
#  Row(source_page='other-search', target_page='List_of_Playboy_Playmates_of_the_Month', link_category='external', click_count=30343),
#  Row(source_page='other-search', target_page='Mindtree', link_category='external', click_count=11028),
#  Row(source_page='other-empty', target_page='Rose_Kennedy', link_category='external', click_count=24838),
#  Row(source_page='other-search', target_page='Maned_wolf', link_category='external', click_count=10794),
#  Row(source_page='other-search', target_page='The_Call_of_Cthulhu', link_category='external', click_count=13954),
#  Row(source_page='other-search', target_page='ACF_Fiorentina', link_category='external', click_count=10912),
#  Row(source_page='other-search', target_page='Wasabi', link_category='external', click_count=40571),
#  Row(source_page='other-empty', target_page='Wasabi', link_category='external', click_count=11914),
#  Row(source_page='other-search', target_page='Of_Mice_&_Men_(band)', link_category='external', click_count=26487),
#  Row(source_page='other-search', target_page='Jews', link_category='external', click_count=100085),
#  Row(source_page='other-empty', target_page='Jews', link_category='external', click_count=57390),
#  Row(source_page='other-empty', target_page='Ash_Wednesday', link_category='external', click_count=16102),
#  Row(source_page='other-search', target_page='Ash_Wednesday', link_category='external', click_count=38502),
#  Row(source_page='other-search', target_page='Sid_Eudy', link_category='external', click_count=16236),
#  Row(source_page='other-empty', target_page='Sid_Eudy', link_category='external', click_count=10006),
#  Row(source_page='other-search', target_page='Homecoming', link_category='external', click_count=16393),
#  Row(source_page='other-empty', target_page='Kumquat', link_category='external', click_count=13459),
#  Row(source_page='other-search', target_page='Kumquat', link_category='external', click_count=35835),
#  Row(source_page='other-search', target_page="22nd_Critics'_Choice_Awards", link_category='external', click_count=12380),
#  Row(source_page='other-search', target_page='Neuroplasticity', link_category='external', click_count=19185),
#  Row(source_page='other-search', target_page='Rob_Holding', link_category='external', click_count=14605),
#  Row(source_page='other-search', target_page='The_Carnival_of_the_Animals', link_category='external', click_count=12615),
#  Row(source_page='other-search', target_page='Konohana_Kitan', link_category='external', click_count=10855),
#  Row(source_page='other-empty', target_page='IPad_(2017)', link_category='external', click_count=12542),
#  Row(source_page='other-search', target_page='IPad_(2017)', link_category='external', click_count=20629),
#  Row(source_page='other-search', target_page="JoJo's_Bizarre_Adventure:_Stardust_Crusaders", link_category='external', click_count=11064),
#  Row(source_page='other-search', target_page='HNA_Group', link_category='external', click_count=14752),
#  Row(source_page='Shah_Rukh_Khan_filmography', target_page='Zero_(2018_film)', link_category='link', click_count=12194),
#  Row(source_page='other-search', target_page='Zero_(2018_film)', link_category='external', click_count=75789),
#  Row(source_page='other-empty', target_page='Zero_(2018_film)', link_category='external', click_count=46319),
#  Row(source_page='other-search', target_page='USS_Liberty_incident', link_category='external', click_count=15174),
#  Row(source_page='other-search', target_page="Shakespeare's_plays", link_category='external', click_count=21915),
#  Row(source_page='other-empty', target_page="Shakespeare's_plays", link_category='external', click_count=10713),
#  Row(source_page='other-empty', target_page='India_Summer', link_category='external', click_count=10032),
#  Row(source_page='other-search', target_page='India_Summer', link_category='external', click_count=28118),
#  Row(source_page='other-empty', target_page='Aaron_Burr', link_category='external', click_count=49154),
#  Row(source_page='other-search', target_page='Aaron_Burr', link_category='external', click_count=66205),
#  Row(source_page='other-search', target_page='Gutenberg_Bible', link_category='external', click_count=14868),
#  Row(source_page='YouTube', target_page='Chad_Hurley', link_category='link', click_count=11002),
#  Row(source_page='other-search', target_page='Illegal_immigration_to_the_United_States', link_category='external', click_count=25114),
#  Row(source_page='other-search', target_page='Friedrich_Paulus', link_category='external', click_count=10794),
#  Row(source_page='other-empty', target_page='The_Rise_and_Fall_of_Ziggy_Stardust_and_the_Spiders_from_Mars', link_category='external', click_count=12969),
#  Row(source_page='other-search', target_page='The_Rise_and_Fall_of_Ziggy_Stardust_and_the_Spiders_from_Mars', link_category='external', click_count=13453),
#  Row(source_page='other-search', target_page="George_O'Malley", link_category='external', click_count=33604),
#  Row(source_page='other-empty', target_page="George_O'Malley", link_category='external', click_count=15088),
#  Row(source_page='other-search', target_page='Jallianwala_Bagh_massacre', link_category='external', click_count=51065),
#  Row(source_page='other-empty', target_page='Jallianwala_Bagh_massacre', link_category='external', click_count=22605),
#  Row(source_page='other-search', target_page='Hitman_(series)', link_category='external', click_count=27227),
#  Row(source_page='other-search', target_page='Liquid', link_category='external', click_count=13787),
#  Row(source_page='other-search', target_page='The_Raft_of_the_Medusa', link_category='external', click_count=11622),
#  Row(source_page='XVideos', target_page='List_of_most_popular_websites', link_category='link', click_count=13129),
#  Row(source_page='other-search', target_page='List_of_most_popular_websites', link_category='external', click_count=146313),
#  Row(source_page='other-empty', target_page='List_of_most_popular_websites', link_category='external', click_count=36024),
#  Row(source_page='other-search', target_page='Ion_chromatography', link_category='external', click_count=10151),
#  Row(source_page='other-empty', target_page='Airbus_A330neo', link_category='external', click_count=10049),
#  Row(source_page='other-search', target_page='Airbus_A330neo', link_category='external', click_count=12981),
#  Row(source_page='other-search', target_page='Satoru_Iwata', link_category='external', click_count=12161),
#  Row(source_page='other-search', target_page='List_of_tie-breaking_votes_cast_by_vice_presidents_of_the_United_States', link_category='external', click_count=11681),
#  Row(source_page='other-empty', target_page='Dragon_(zodiac)', link_category='external', click_count=11260),
#  Row(source_page='other-search', target_page='Dragon_(zodiac)', link_category='external', click_count=23332),
#  Row(source_page='other-empty', target_page='John_Mara', link_category='external', click_count=11440),
#  Row(source_page='other-empty', target_page='Strip_club', link_category='external', click_count=13462),
#  Row(source_page='other-search', target_page='Strip_club', link_category='external', click_count=10935),
# ...
#  Row(source_page='other-empty', target_page='Arizona_Cardinals', link_category='external', click_count=23231),
#  Row(source_page='Muhammad_bin_Tughluq', target_page='Firuz_Shah_Tughlaq', link_category='link', click_count=11784),
#  Row(source_page='other-search', target_page='Arizona_Cardinals', link_category='external', click_count=27174),
#  Row(source_page='other-empty', target_page='Twitter', link_category='external', click_count=71701),
#  Row(source_page='other-search', target_page='Twitter', link_category='external', click_count=110067),
#  Row(source_page='other-search', target_page='Remittance', link_category='external', click_count=11287),
#  Row(source_page='other-search', target_page='Maria_Goretti', link_category='external', click_count=12621),
#  Row(source_page='other-search', target_page='Kris_Dunn', link_category='external', click_count=25623),
#  Row(source_page='The_Post_(film)', target_page='Sarah_Paulson', link_category='link', click_count=15465),
#  Row(source_page='other-search', target_page='Sarah_Paulson', link_category='external', click_count=100762),
#  Row(source_page='other-empty', target_page='Sarah_Paulson', link_category='external', click_count=93019),
#  Row(source_page='Holland_Taylor', target_page='Sarah_Paulson', link_category='link', click_count=11387),
#  Row(source_page='other-search', target_page='Future_Diary', link_category='external', click_count=31903),
#  Row(source_page='other-empty', target_page='Arnold_Strongman_Classic', link_category='external', click_count=16730),
#  Row(source_page='other-search', target_page='Arnold_Strongman_Classic', link_category='external', click_count=51422),
#  Row(source_page='other-search', target_page='Alex_de_Minaur', link_category='external', click_count=184746),
#  Row(source_page='other-empty', target_page='Alex_de_Minaur', link_category='external', click_count=51700),
#  Row(source_page='other-search', target_page='Tranny_(slang)', link_category='external', click_count=10567),
#  Row(source_page='other-empty', target_page='Kalief_Browder', link_category='external', click_count=17235),
#  Row(source_page='other-search', target_page='Kalief_Browder', link_category='external', click_count=53481),
#  Row(source_page='other-search', target_page='Hadith', link_category='external', click_count=13891),
#  Row(source_page='other-empty', target_page='Hadith', link_category='external', click_count=11869),
#  Row(source_page='other-search', target_page='Spaghetti_alla_puttanesca', link_category='external', click_count=12539),
#  Row(source_page='other-empty', target_page='Nancy_Benoit', link_category='external', click_count=10954),
#  Row(source_page='other-search', target_page='Kushboo', link_category='external', click_count=26252),
#  Row(source_page='other-search', target_page='Theanine', link_category='external', click_count=16872),
#  Row(source_page='other-empty', target_page='Tamil_Rockers', link_category='external', click_count=28782),
#  Row(source_page='other-search', target_page='Tamil_Rockers', link_category='external', click_count=157731),
#  Row(source_page='other-search', target_page='Scooter_(band)', link_category='external', click_count=14780),
#  Row(source_page='other-search', target_page='Blue_Beetle', link_category='external', click_count=11065),
#  Row(source_page='other-search', target_page='Sally_Quinn', link_category='external', click_count=13187),
#  Row(source_page='Ben_Bradlee', target_page='Sally_Quinn', link_category='link', click_count=10138),
#  Row(source_page='other-empty', target_page='Sally_Quinn', link_category='external', click_count=23342),
#  Row(source_page='other-empty', target_page='Blaise_Pascal', link_category='external', click_count=12999),
#  Row(source_page='other-search', target_page='Blaise_Pascal', link_category='external', click_count=27298),
#  Row(source_page='other-search', target_page='Vic_Mignogna', link_category='external', click_count=15022),
#  Row(source_page='other-search', target_page="Tom_Clancy's_The_Division", link_category='external', click_count=31704),
#  Row(source_page='other-search', target_page='Color_in_Chinese_culture', link_category='external', click_count=11932),
#  Row(source_page='other-search', target_page='Perkin_Warbeck', link_category='external', click_count=11604),
#  Row(source_page='other-search', target_page='Simon_&_Garfunkel', link_category='external', click_count=42311),
#  Row(source_page='other-empty', target_page='Simon_&_Garfunkel', link_category='external', click_count=21436),
#  Row(source_page='other-search', target_page='First_Boer_War', link_category='external', click_count=12316),
#  Row(source_page='other-search', target_page='Common_starling', link_category='external', click_count=14953),
#  Row(source_page='other-empty', target_page='Frank_Dukes', link_category='external', click_count=10139),
#  Row(source_page='other-search', target_page='Chalazion', link_category='external', click_count=16467),
#  Row(source_page='other-empty', target_page='Chalazion', link_category='external', click_count=10749),
#  Row(source_page='other-search', target_page='Illustration', link_category='external', click_count=10519),
#  Row(source_page='other-search', target_page='Carol_(film)', link_category='external', click_count=39322),
#  Row(source_page='other-empty', target_page='Carol_(film)', link_category='external', click_count=13528),
#  Row(source_page='other-search', target_page="That_'70s_Show_(season_8)", link_category='external', click_count=15150),
#  Row(source_page='other-empty', target_page='Polyglotism', link_category='external', click_count=19645),
#  Row(source_page='other-search', target_page='Polyglotism', link_category='external', click_count=11329),
#  Row(source_page='other-search', target_page='Brazil_v_Germany_(2014_FIFA_World_Cup)', link_category='external', click_count=10300),
#  Row(source_page='other-search', target_page='In_situ', link_category='external', click_count=13164),
#  Row(source_page='other-search', target_page='Chandler_Parsons', link_category='external', click_count=10675),
#  Row(source_page='other-search', target_page='Haters_Back_Off', link_category='external', click_count=21185),
#  Row(source_page='other-search', target_page='Amanda_Lamb', link_category='external', click_count=15931),
#  Row(source_page='other-search', target_page='Glossary_of_names_for_the_British', link_category='external', click_count=10713),
#  Row(source_page='other-search', target_page='Muscles_of_the_hip', link_category='external', click_count=12258),
#  Row(source_page='other-search', target_page='Amy_Jo_Johnson', link_category='external', click_count=14801),
#  Row(source_page='other-empty', target_page='Amy_Jo_Johnson', link_category='external', click_count=13390),
#  Row(source_page='other-search', target_page='The_Box_(2009_film)', link_category='external', click_count=38781),
#  Row(source_page='other-empty', target_page='The_Box_(2009_film)', link_category='external', click_count=10909),
#  Row(source_page='other-empty', target_page='Carbuncle', link_category='external', click_count=10848),
#  Row(source_page='other-empty', target_page='Sole_proprietorship', link_category='external', click_count=21266),
#  Row(source_page='other-search', target_page='Sole_proprietorship', link_category='external', click_count=22106),
#  Row(source_page='other-search', target_page='Serous_membrane', link_category='external', click_count=10730),
#  Row(source_page='other-search', target_page='John_Snow', link_category='external', click_count=17637),
#  Row(source_page='Doctor_Who', target_page='List_of_Doctor_Who_episodes_(2005–present)', link_category='link', click_count=14635),
#  Row(source_page='other-empty', target_page='List_of_Doctor_Who_episodes_(2005–present)', link_category='external', click_count=20047),
#  Row(source_page='List_of_Doctor_Who_episodes', target_page='List_of_Doctor_Who_episodes_(2005–present)', link_category='link', click_count=20937),
#  Row(source_page='other-search', target_page="Heaven's_Gate_(religious_group)", link_category='external', click_count=101488),
#  Row(source_page='other-empty', target_page="Heaven's_Gate_(religious_group)", link_category='external', click_count=20831),
#  Row(source_page='other-search', target_page="Men's_100_metres_world_record_progression", link_category='external', click_count=12253),
#  Row(source_page='other-search', target_page='Bessel_function', link_category='external', click_count=22436),
#  Row(source_page='other-empty', target_page='The_Inpatient', link_category='external', click_count=11540),
#  Row(source_page='other-search', target_page='The_Inpatient', link_category='external', click_count=31337),
#  Row(source_page='other-search', target_page='Pancreatitis', link_category='external', click_count=23978),
#  Row(source_page='other-empty', target_page='Pancreatitis', link_category='external', click_count=60310),
#  Row(source_page='other-search', target_page='Supermarket_Sweep', link_category='external', click_count=12121),
#  Row(source_page='other-search', target_page='Greg_Louganis', link_category='external', click_count=12090),
#  Row(source_page='other-empty', target_page='Three_Gorges_Dam', link_category='external', click_count=11167),
#  Row(source_page='other-search', target_page='Three_Gorges_Dam', link_category='external', click_count=30539),
#  Row(source_page='other-empty', target_page='Supply_chain_management', link_category='external', click_count=16681),
#  Row(source_page='other-search', target_page='Supply_chain_management', link_category='external', click_count=51100),
#  Row(source_page='other-internal', target_page='Coco_(2017_film)', link_category='external', click_count=21379),
#  Row(source_page='other-search', target_page='Mail_(armour)', link_category='external', click_count=10815),
#  Row(source_page='other-empty', target_page='Coco_(2017_film)', link_category='external', click_count=162214),
#  Row(source_page='Coco', target_page='Coco_(2017_film)', link_category='link', click_count=12309),
#  Row(source_page='other-search', target_page='Coco_(2017_film)', link_category='external', click_count=489731),
#  Row(source_page='List_of_Pixar_films', target_page='Coco_(2017_film)', link_category='link', click_count=10347),
#  Row(source_page='other-search', target_page='Morgan_Stanley', link_category='external', click_count=25712),
#  Row(source_page='other-empty', target_page='Morgan_Stanley', link_category='external', click_count=10213),
#  Row(source_page='other-search', target_page='ER_(season_1)', link_category='external', click_count=17141),
#  Row(source_page='other-empty', target_page='ER_(season_1)', link_category='external', click_count=10919),
#  Row(source_page='other-search', target_page='Sajan_Re_Phir_Jhooth_Mat_Bolo', link_category='external', click_count=25915),
#  Row(source_page='other-empty', target_page='Edward_the_Elder', link_category='external', click_count=16388),
#  Row(source_page='other-search', target_page='Radioactive_decay', link_category='external', click_count=31655),
#  Row(source_page='other-empty', target_page='Radioactive_decay', link_category='external', click_count=19665),
#  Row(source_page='other-search', target_page='Spectrum', link_category='external', click_count=11390),
#  Row(source_page='other-search', target_page='Ryan_Shazier', link_category='external', click_count=76916),
#  Row(source_page='other-empty', target_page='Breitbart_News', link_category='external', click_count=28149),
#  Row(source_page='other-empty', target_page='Ryan_Shazier', link_category='external', click_count=15092),
#  Row(source_page='other-search', target_page='Breitbart_News', link_category='external', click_count=75529),
#  Row(source_page='other-search', target_page='Adder_(electronics)', link_category='external', click_count=15532),
#  Row(source_page='other-search', target_page='Air_Jordan', link_category='external', click_count=36195),
#  Row(source_page='other-empty', target_page='Air_Jordan', link_category='external', click_count=15429),
#  Row(source_page='other-search', target_page='The_Perfect_Storm_(film)', link_category='external', click_count=19619),
#  Row(source_page='other-search', target_page='Bartending_terminology', link_category='external', click_count=14866),
#  Row(source_page='other-empty', target_page='Hypatia', link_category='external', click_count=10961),
#  Row(source_page='other-search', target_page='Hypatia', link_category='external', click_count=23054),
#  Row(source_page='other-search', target_page='My_Korean_Jagiya', link_category='external', click_count=10842),
#  Row(source_page='other-search', target_page='Aphrodite', link_category='external', click_count=51442),
#  Row(source_page='other-empty', target_page='Aphrodite', link_category='external', click_count=39134),
#  Row(source_page='other-empty', target_page='Pseudonym', link_category='external', click_count=22768),
#  Row(source_page='other-search', target_page="Goethe's_Faust", link_category='external', click_count=10644),
#  Row(source_page='other-empty', target_page='2002–03_NFL_playoffs', link_category='external', click_count=13926),
#  Row(source_page='other-search', target_page='Ōkami', link_category='external', click_count=22066),
#  Row(source_page='other-empty', target_page='Seven_gifts_of_the_Holy_Spirit', link_category='external', click_count=10006),
#  Row(source_page='other-search', target_page='Seven_gifts_of_the_Holy_Spirit', link_category='external', click_count=30483),
#  Row(source_page='Star_Wars:_The_Clone_Wars_(2008_TV_series)', target_page='List_of_Star_Wars:_The_Clone_Wars_episodes', link_category='link', click_count=16047),
#  Row(source_page='other-search', target_page='List_of_Star_Wars:_The_Clone_Wars_episodes', link_category='external', click_count=23378),
#  Row(source_page='other-empty', target_page='List_of_Star_Wars:_The_Clone_Wars_episodes', link_category='external', click_count=18494),
#  Row(source_page='other-search', target_page='Hathor', link_category='external', click_count=13075),
#  Row(source_page='other-search', target_page='Non-compete_clause', link_category='external', click_count=12889),
#  Row(source_page='other-empty', target_page='Larsen_&_Toubro', link_category='external', click_count=20235),
#  Row(source_page='other-search', target_page='Larsen_&_Toubro', link_category='external', click_count=37652),
#  Row(source_page='other-search', target_page='Rent_(film)', link_category='external', click_count=16306),
#  Row(source_page='other-search', target_page='Impact_event', link_category='external', click_count=10587),
#  Row(source_page='other-search', target_page='Hyundai', link_category='external', click_count=16284),
#  Row(source_page='other-search', target_page='Death_Stranding', link_category='external', click_count=68665),
#  Row(source_page='other-empty', target_page='Death_Stranding', link_category='external', click_count=16847),
#  Row(source_page='other-empty', target_page='Rochdale_Cenotaph', link_category='external', click_count=17507),
#  Row(source_page='Main_Page', target_page='Rochdale_Cenotaph', link_category='other', click_count=17060),
#  Row(source_page='other-empty', target_page='Mobile_operating_system', link_category='external', click_count=12439),
#  Row(source_page='other-search', target_page='Mobile_operating_system', link_category='external', click_count=12926),
#  Row(source_page='other-search', target_page='Black_panther', link_category='external', click_count=76255),
#  Row(source_page='other-empty', target_page='Black_panther', link_category='external', click_count=26758),
#  Row(source_page='other-search', target_page='United_States_Attorney', link_category='external', click_count=10526),
#  Row(source_page='other-search', target_page='Between_the_Buried_and_Me', link_category='external', click_count=13824),
#  Row(source_page='other-search', target_page='Grip_(job)', link_category='external', click_count=10776),
#  Row(source_page='other-empty', target_page='Pete_Doherty', link_category='external', click_count=15860),
#  Row(source_page='other-search', target_page='Pete_Doherty', link_category='external', click_count=21278),
#  ...]

# %%
babylon_table\
.filter(babylon_table.target_page == "Hanging_Gardens_of_Babylon")\
.orderBy(babylon_table.click_count, ascending=False)\
.show(truncate=False)
# Out:
# +----------------------------------+--------------------------+-------------+-----------+
# |source_page                       |target_page               |link_category|click_count|
# +----------------------------------+--------------------------+-------------+-----------+
# |other-search                      |Hanging_Gardens_of_Babylon|external     |47088      |
# |other-empty                       |Hanging_Gardens_of_Babylon|external     |34619      |
# |Wonders_of_the_World              |Hanging_Gardens_of_Babylon|link         |14668      |
# |Seven_Wonders_of_the_Ancient_World|Hanging_Gardens_of_Babylon|link         |12296      |
# +----------------------------------+--------------------------+-------------+-----------+

# %% [markdown]
# ### Task 10
#
# Perform the same analysis as the previous exercise using a SQL query.

# %%
# Filter and sort the DataFrame using SQL
result = spark.sql("""
SELECT * FROM clickstream_view
WHERE target_page = 'Hanging_Gardens_of_Babylon'
ORDER BY click_count DESC
""")
result.printSchema()
result.show(10, truncate=False)
# Out:
# root
#  |-- source_page: string (nullable = true)
#  |-- target_page: string (nullable = true)
#  |-- link_category: string (nullable = true)
#  |-- click_count: integer (nullable = true)
#
# +----------------------------------+--------------------------+-------------+-----------+
# |source_page                       |target_page               |link_category|click_count|
# +----------------------------------+--------------------------+-------------+-----------+
# |other-search                      |Hanging_Gardens_of_Babylon|external     |47088      |
# |other-empty                       |Hanging_Gardens_of_Babylon|external     |34619      |
# |Wonders_of_the_World              |Hanging_Gardens_of_Babylon|link         |14668      |
# |Seven_Wonders_of_the_Ancient_World|Hanging_Gardens_of_Babylon|link         |12296      |
# +----------------------------------+--------------------------+-------------+-----------+

# %% [markdown]
# ### Task 11
#
# Calculate the sum of `click_count` grouped by `link_category` using PySpark DataFrame methods.

# %%
# Aggregate the DataFrame using PySpark DataFrame Methods 
babylon_table\
.groupBy(babylon_table.link_category)\
.sum()\
.orderBy("sum(click_count)", ascending=False)\
.show(truncate=False)
# Out:
# +-------------+----------------+
# |link_category|sum(click_count)|
# +-------------+----------------+
# |external     |3248677856      |
# |link         |97805811        |
# |other        |9338172         |
# +-------------+----------------+

# %% [markdown]
# ### Task 12
#
# Perform the same analysis as the previous exercise using a SQL query.

# %%
spark.sql(
    """
    SELECT *
    FROM clickstream_view
    LIMIT 5
    """
).show(truncate=False)
# Out:
# +-------------------+--------------+-------------+-----------+
# |source_page        |target_page   |link_category|click_count|
# +-------------------+--------------+-------------+-----------+
# |Daniel_Day-Lewis   |Phantom_Thread|link         |43190      |
# |other-internal     |Phantom_Thread|external     |21683      |
# |other-empty        |Phantom_Thread|external     |169532     |
# |90th_Academy_Awards|Phantom_Thread|link         |40449      |
# |other-search       |Phantom_Thread|external     |536940     |
# +-------------------+--------------+-------------+-----------+

# %%
# Aggregate the DataFrame using SQL
spark.sql(
    """
    SELECT link_category, SUM(click_count) AS links_count
    FROM clickstream_view
    GROUP BY link_category
    ORDER BY links_count DESC
    """
).show(truncate=False)
# Out:
# +-------------+-----------+
# |link_category|links_count|
# +-------------+-----------+
# |external     |3248677856 |
# |link         |97805811   |
# |other        |9338172    |
# +-------------+-----------+

# %% [markdown]
# ## Task Group 4 - Saving Results to Disk

# %% [markdown]
# ### Task 13
#
# Let's create a new DataFrame named `internal_clickstream` that only contains article pairs where `link_category` is `link`. Use `filter()` to select rows to a specific condition and `select()` to choose which columns to return from the query.

# %%
# Create a new DataFrame named `internal_clickstream`
internal_clickstream = clickstream_df\
.filter(clickstream_df.link_category == "link")\
.drop("link_category")

# Display the first few rows of the DataFrame in the notebook
internal_clickstream.show(5, truncate=False)
# Out:
# +-------------------+----------------------+-----------+
# |source_page        |target_page           |click_count|
# +-------------------+----------------------+-----------+
# |Daniel_Day-Lewis   |Phantom_Thread        |43190      |
# |90th_Academy_Awards|Phantom_Thread        |40449      |
# |Shinee             |Kim_Jong-hyun_(singer)|24433      |
# |Agnyaathavaasi     |Anu_Emmanuel          |15020      |
# |Naa_Peru_Surya     |Anu_Emmanuel          |12361      |
# +-------------------+----------------------+-----------+
# only showing top 5 rows

# %% [markdown]
# ### Task 14
#
# Using `DataFrame.write.csv()`, save the `internal_clickstream` DataFrame as CSV files in a directory called `./results/article_to_article_csv/`.

# %%
# Save the `internal_clickstream` DataFrame to a series of CSV files
internal_clickstream.write.csv("./notebook-output/article_to_article_csv")

# %%
spark.read\
    .option('header', False) \
    .option('delimiter', ',') \
    .option('inferSchema', True) \
.csv("./notebook-output/article_to_article_csv")\
.show(5, truncate=False)
# Out:
# +-------------------+----------------------+-----+
# |_c0                |_c1                   |_c2  |
# +-------------------+----------------------+-----+
# |Daniel_Day-Lewis   |Phantom_Thread        |43190|
# |90th_Academy_Awards|Phantom_Thread        |40449|
# |Shinee             |Kim_Jong-hyun_(singer)|24433|
# |Agnyaathavaasi     |Anu_Emmanuel          |15020|
# |Naa_Peru_Surya     |Anu_Emmanuel          |12361|
# +-------------------+----------------------+-----+
# only showing top 5 rows

# %% [markdown]
# ### Task 15
#
# Using `DataFrame.write.parquet()`, save the `internal_clickstream` DataFrame as parquet files in a directory called `./results/article_to_article_pq/`.

# %%
# Save the `internal_clickstream` DataFrame to a series of parquet files
internal_clickstream.write.parquet("./notebook-output/article_to_article_pq")

# %% [markdown]
# ### Task 16
#
# Close the `SparkSession` and underlying `SparkContext`. What happens if you we call `clickstream.show()` after closing the `SparkSession`?

# %%
# Stop the notebook's `SparkSession` and `SparkContext`
spark.stop()

# %%
# The SparkSession and sparkContext are stopped; the following line will throw an error:
clickstream.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[75], line 2
#       1 # The SparkSession and sparkContext are stopped; the following line will throw an error:
# ----> 2 clickstream.show()
#
# AttributeError: 'NoneType' object has no attribute 'show'
